# %% [markdown]
# # 3D Pursuit

# %%
from src.grid import Grid3D
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from src.grid import Grid3D
#
# File ~/3d-pursuit-rollout/src/grid.py:2
#       1 import numpy as np
# ----> 2 from data_types.postion import Position
#       4 class Grid3D:
#       5     def __init__(self, width, height, depth):
#
# ModuleNotFoundError: No module named 'data_types'
